# %%
import numpy as np

# %%
A = np.array([[2, -1], [0, 3]])

B = np.array([[1, 4], [-2, 5]])

c = 2

d = 3

#Computing the following: (cA),(dB),and (c + d)A

cA = np.dot(c,A)
cA

dB = np.dot(d,B)
dB
# dB = ([[3, 12],
#        [-6, 15]])

(c + d) = np.add(c,d)

# (c+d) A = ([[10, -5],
#             [0, 15]])
# Out:
#   Cell In[7], line 19
#
#     (c + d) A = 5 ([[2, -1],
#
#             ^
#
# SyntaxError: invalid syntax
